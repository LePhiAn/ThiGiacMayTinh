# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("tao2.mp4")
assert cap.isOpened(), "Error reading video file"

# region_points = [(20, 400), (1080, 400)]                                      # line counting
region_points = [[0, 207], [1019, 213], [1019, 213], [1012, 570], [1012, 570], [5, 570]]  # rectangular region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon region

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize object counter object
counter = solutions.ObjectCounter(
    show=True,  # display the output
    region=region_points,  # pass region points
    model="yolo11n.pt",  # model="yolo26n-obb.pt" for object counting with OBB model.
    # classes=[0, 2],  # count specific classes, e.g., person and car with the COCO pretrained model.
    # tracker="botsort.yaml",  # choose trackers, e.g., "bytetrack.yaml"
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = counter(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [[0, 207], [1019, 213], [1019, 213], [1012, 570], [1012, 570], [5, 570]], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 432x768 34.1ms, 6 apple
# Speed: 209.6ms track, 34.1ms solution per image at shape (1, 3, 432, 768)
#
# 1: 432x768 4.2ms, 5 apple
# Speed: 83.9ms track, 4.2ms solution per image at shape (1, 3, 432, 768)
#
# 2: 432x768 17.8ms, 6 apple
# Speed: 76.7ms track, 17.8ms solution per image at shape (1, 3, 432, 768)
#
# 3: 432x768 15.7ms, 8 apple
# Speed: 89.0ms track, 15.7ms solution per image at shape (1, 3, 432, 768)
#
# 4: 432x768 8.9ms, 7 apple
# Speed: 79.6ms track, 8.9ms solution per image at shape (1, 3, 432, 768)
#
# 5: 432x768 13.8ms, 8 apple
# Speed: 89.2ms track, 13.8ms solution per image at shape (1, 3, 432, 768)
#
# 6: 432x768 17.2ms, 8 apple
# Speed: 73.4ms track, 17.2ms solution per image at shape (1, 3, 432, 768)
#
# 7: 432x768 17.0ms, 9 apple
# Speed: 70.5ms track, 17.0ms solution per image at shape (1, 3, 432, 768)
#
# 8: 432x768 8.0ms, 9 apple
# Speed: 81.0ms track, 8.0ms solution per image at shape (1, 3, 432, 768)
#
# 9: 432x768 4.6ms, 10 apple
# Speed: 101.8ms track, 4.6ms solution per image at shape (1, 3, 432, 768)
#
# 10: 432x768 7.8ms, 9 apple
# Speed: 91.9ms track, 7.8ms solution per image at shape (1, 3, 432, 768)
#
# 11: 432x768 13.8ms, 9 apple
# Speed: 75.0ms track, 13.8ms solution per image at shape (1, 3, 432, 768)
#
# 12: 432x768 13.2ms, 8 apple
# Speed: 74.6ms track, 13.2ms solution per image at shape (1, 3, 432, 768)
#
# 13: 432x768 3.9ms, 8 apple
# Speed: 68.3ms track, 3.9ms solution per image at shape (1, 3, 432, 768)
#
# 14: 432x768 11.9ms, 9 apple
# Speed: 62.0ms track, 11.9ms solution per image at shape (1, 3, 432, 768)
#
# 15: 432x768 13.6ms, 9 apple
# Speed: 61.8ms track, 13.6ms solution per image at shape (1, 3, 432, 768)
#
# 16: 432x768 17.8ms, 9 apple
# Speed: 71.9ms track, 17.8ms solution per image at shape (1, 3, 432, 768)
#
# 17: 432x768 4.0ms, 8 apple
# Speed: 69.9ms track, 4.0ms solution per image at shape (1, 3, 432, 768)
#
# 18: 432x768 5.8ms, 7 apple
# Speed: 66.8ms track, 5.8ms solution per image at shape (1, 3, 432, 768)
#
# 19: 432x768 15.2ms, 7 apple
# Speed: 73.7ms track, 15.2ms solution per image at shape (1, 3, 432, 768)
#
# 20: 432x768 14.9ms, 7 apple
# Speed: 70.2ms track, 14.9ms solution per image at shape (1, 3, 432, 768)
#
# 21: 432x768 15.6ms, 7 apple
# Speed: 67.7ms track, 15.6ms solution per image at shape (1, 3, 432, 768)
#
# 22: 432x768 11.1ms, 7 apple
# Speed: 68.5ms track, 11.1ms solution per image at shape (1, 3, 432, 768)
#
# 23: 432x768 9.4ms, 7 apple
# Speed: 69.3ms track, 9.4ms solution per image at shape (1, 3, 432, 768)
#
# 24: 432x768 8.7ms, 7 apple
# Speed: 70.6ms track, 8.7ms solution per image at shape (1, 3, 432, 768)
#
# 25: 432x768 7.0ms, 7 apple
# Speed: 70.5ms track, 7.0ms solution per image at shape (1, 3, 432, 768)
#
# 26: 432x768 3.3ms, 6 apple
# Speed: 65.6ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 27: 432x768 6.3ms, 7 apple
# Speed: 70.3ms track, 6.3ms solution per image at shape (1, 3, 432, 768)
#
# 28: 432x768 3.0ms, 7 apple
# Speed: 63.9ms track, 3.0ms solution per image at shape (1, 3, 432, 768)
#
# 29: 432x768 15.7ms, 8 apple
# Speed: 73.6ms track, 15.7ms solution per image at shape (1, 3, 432, 768)
#
# 30: 432x768 9.2ms, 7 apple
# Speed: 66.7ms track, 9.2ms solution per image at shape (1, 3, 432, 768)
#
# 31: 432x768 3.3ms, 7 apple
# Speed: 59.5ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 32: 432x768 13.2ms, 7 apple
# Speed: 69.8ms track, 13.2ms solution per image at shape (1, 3, 432, 768)
#
# 33: 432x768 17.7ms, 7 apple
# Speed: 68.4ms track, 17.7ms solution per image at shape (1, 3, 432, 768)
#
# 34: 432x768 3.5ms, 7 apple
# Speed: 68.1ms track, 3.5ms solution per image at shape (1, 3, 432, 768)
#
# 35: 432x768 8.9ms, 7 apple
# Speed: 71.3ms track, 8.9ms solution per image at shape (1, 3, 432, 768)
#
# 36: 432x768 7.1ms, 6 apple
# Speed: 63.1ms track, 7.1ms solution per image at shape (1, 3, 432, 768)
#
# 37: 432x768 3.6ms, 6 apple
# Speed: 67.2ms track, 3.6ms solution per image at shape (1, 3, 432, 768)
#
# 38: 432x768 4.4ms, 6 apple
# Speed: 67.3ms track, 4.4ms solution per image at shape (1, 3, 432, 768)
#
# 39: 432x768 17.5ms, 6 apple
# Speed: 64.2ms track, 17.5ms solution per image at shape (1, 3, 432, 768)
#
# 40: 432x768 2.6ms, 6 apple
# Speed: 70.0ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# 41: 432x768 14.1ms, 6 apple
# Speed: 69.0ms track, 14.1ms solution per image at shape (1, 3, 432, 768)
#
# 42: 432x768 8.7ms, 6 apple
# Speed: 69.0ms track, 8.7ms solution per image at shape (1, 3, 432, 768)
#
# 43: 432x768 4.0ms, 5 apple
# Speed: 62.0ms track, 4.0ms solution per image at shape (1, 3, 432, 768)
#
# 44: 432x768 17.5ms, 5 apple
# Speed: 68.7ms track, 17.5ms solution per image at shape (1, 3, 432, 768)
#
# 45: 432x768 4.4ms, 6 apple
# Speed: 64.8ms track, 4.4ms solution per image at shape (1, 3, 432, 768)
#
# 46: 432x768 9.0ms, 6 apple
# Speed: 65.0ms track, 9.0ms solution per image at shape (1, 3, 432, 768)
#
# 47: 432x768 10.2ms, 5 apple
# Speed: 63.5ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# 48: 432x768 14.3ms, 5 apple
# Speed: 63.9ms track, 14.3ms solution per image at shape (1, 3, 432, 768)
#
# 49: 432x768 4.5ms, 5 apple
# Speed: 67.9ms track, 4.5ms solution per image at shape (1, 3, 432, 768)
#
# 50: 432x768 14.9ms, 5 apple
# Speed: 65.7ms track, 14.9ms solution per image at shape (1, 3, 432, 768)
#
# 51: 432x768 7.2ms, 5 apple
# Speed: 68.6ms track, 7.2ms solution per image at shape (1, 3, 432, 768)
#
# 52: 432x768 7.8ms, 5 apple
# Speed: 60.8ms track, 7.8ms solution per image at shape (1, 3, 432, 768)
#
# 53: 432x768 6.0ms, 6 apple
# Speed: 59.1ms track, 6.0ms solution per image at shape (1, 3, 432, 768)
#
# 54: 432x768 3.3ms, 6 apple
# Speed: 63.0ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 55: 432x768 7.8ms, 6 apple
# Speed: 67.4ms track, 7.8ms solution per image at shape (1, 3, 432, 768)
#
# 56: 432x768 16.0ms, 6 apple
# Speed: 64.1ms track, 16.0ms solution per image at shape (1, 3, 432, 768)
#
# 57: 432x768 11.3ms, 7 apple
# Speed: 57.0ms track, 11.3ms solution per image at shape (1, 3, 432, 768)
#
# 58: 432x768 6.4ms, 7 apple
# Speed: 60.2ms track, 6.4ms solution per image at shape (1, 3, 432, 768)
#
# 59: 432x768 6.3ms, 7 apple
# Speed: 59.3ms track, 6.3ms solution per image at shape (1, 3, 432, 768)
#
# 60: 432x768 16.3ms, 7 apple
# Speed: 63.6ms track, 16.3ms solution per image at shape (1, 3, 432, 768)
#
# 61: 432x768 12.6ms, 7 apple
# Speed: 70.1ms track, 12.6ms solution per image at shape (1, 3, 432, 768)
#
# 62: 432x768 13.7ms, 7 apple
# Speed: 64.3ms track, 13.7ms solution per image at shape (1, 3, 432, 768)
#
# 63: 432x768 4.8ms, 7 apple
# Speed: 58.1ms track, 4.8ms solution per image at shape (1, 3, 432, 768)
#
# 64: 432x768 13.5ms, 7 apple
# Speed: 63.9ms track, 13.5ms solution per image at shape (1, 3, 432, 768)
#
# 65: 432x768 19.2ms, 7 apple
# Speed: 68.0ms track, 19.2ms solution per image at shape (1, 3, 432, 768)
#
# 66: 432x768 15.5ms, 7 apple
# Speed: 99.5ms track, 15.5ms solution per image at shape (1, 3, 432, 768)
#
# 67: 432x768 4.7ms, 7 apple
# Speed: 102.8ms track, 4.7ms solution per image at shape (1, 3, 432, 768)
#
# 68: 432x768 6.0ms, 7 apple
# Speed: 82.6ms track, 6.0ms solution per image at shape (1, 3, 432, 768)
#
# 69: 432x768 8.6ms, 7 apple
# Speed: 72.2ms track, 8.6ms solution per image at shape (1, 3, 432, 768)
#
# 70: 432x768 15.9ms, 7 apple
# Speed: 76.2ms track, 15.9ms solution per image at shape (1, 3, 432, 768)
#
# 71: 432x768 16.3ms, 7 apple
# Speed: 77.8ms track, 16.3ms solution per image at shape (1, 3, 432, 768)
#
# 72: 432x768 4.8ms, 7 apple
# Speed: 72.8ms track, 4.8ms solution per image at shape (1, 3, 432, 768)
#
# 73: 432x768 14.7ms, 7 apple
# Speed: 71.4ms track, 14.7ms solution per image at shape (1, 3, 432, 768)
#
# 74: 432x768 11.4ms, 7 apple
# Speed: 68.9ms track, 11.4ms solution per image at shape (1, 3, 432, 768)
#
# 75: 432x768 2.6ms, 7 apple
# Speed: 71.9ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# 76: 432x768 16.3ms, 7 apple
# Speed: 62.9ms track, 16.3ms solution per image at shape (1, 3, 432, 768)
#
# 77: 432x768 3.2ms, 7 apple
# Speed: 62.2ms track, 3.2ms solution per image at shape (1, 3, 432, 768)
#
# 78: 432x768 11.3ms, 7 apple
# Speed: 62.7ms track, 11.3ms solution per image at shape (1, 3, 432, 768)
#
# 79: 432x768 11.7ms, 7 apple
# Speed: 62.7ms track, 11.7ms solution per image at shape (1, 3, 432, 768)
#
# 80: 432x768 6.7ms, 7 apple
# Speed: 68.1ms track, 6.7ms solution per image at shape (1, 3, 432, 768)
#
# 81: 432x768 14.0ms, 7 apple
# Speed: 65.6ms track, 14.0ms solution per image at shape (1, 3, 432, 768)
#
# 82: 432x768 3.4ms, 7 apple
# Speed: 66.1ms track, 3.4ms solution per image at shape (1, 3, 432, 768)
#
# 83: 432x768 14.9ms, 6 apple
# Speed: 67.9ms track, 14.9ms solution per image at shape (1, 3, 432, 768)
#
# 84: 432x768 8.8ms, 6 apple
# Speed: 69.0ms track, 8.8ms solution per image at shape (1, 3, 432, 768)
#
# 85: 432x768 17.3ms, 5 apple
# Speed: 62.2ms track, 17.3ms solution per image at shape (1, 3, 432, 768)
#
# 86: 432x768 18.2ms, 6 apple
# Speed: 62.4ms track, 18.2ms solution per image at shape (1, 3, 432, 768)
#
# 87: 432x768 9.0ms, 6 apple
# Speed: 66.9ms track, 9.0ms solution per image at shape (1, 3, 432, 768)
#
# 88: 432x768 3.5ms, 6 apple
# Speed: 62.2ms track, 3.5ms solution per image at shape (1, 3, 432, 768)
#
# 89: 432x768 4.9ms, 6 apple
# Speed: 59.7ms track, 4.9ms solution per image at shape (1, 3, 432, 768)
#
# 90: 432x768 3.1ms, 6 apple
# Speed: 64.2ms track, 3.1ms solution per image at shape (1, 3, 432, 768)
#
# 91: 432x768 6.4ms, 6 apple
# Speed: 68.9ms track, 6.4ms solution per image at shape (1, 3, 432, 768)
#
# 92: 432x768 3.8ms, 6 apple
# Speed: 64.3ms track, 3.8ms solution per image at shape (1, 3, 432, 768)
#
# 93: 432x768 12.1ms, 6 apple
# Speed: 64.8ms track, 12.1ms solution per image at shape (1, 3, 432, 768)
#
# 94: 432x768 10.2ms, 6 apple
# Speed: 72.4ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# 95: 432x768 11.1ms, 6 apple
# Speed: 66.2ms track, 11.1ms solution per image at shape (1, 3, 432, 768)
#
# 96: 432x768 11.0ms, 6 apple
# Speed: 65.2ms track, 11.0ms solution per image at shape (1, 3, 432, 768)
#
# 97: 432x768 12.7ms, 6 apple
# Speed: 70.4ms track, 12.7ms solution per image at shape (1, 3, 432, 768)
#
# 98: 432x768 11.6ms, 6 apple
# Speed: 66.8ms track, 11.6ms solution per image at shape (1, 3, 432, 768)
#
# 99: 432x768 5.8ms, 6 apple
# Speed: 72.7ms track, 5.8ms solution per image at shape (1, 3, 432, 768)
#
# 100: 432x768 8.5ms, 6 apple
# Speed: 84.5ms track, 8.5ms solution per image at shape (1, 3, 432, 768)
#
# 101: 432x768 11.8ms, 6 apple
# Speed: 100.4ms track, 11.8ms solution per image at shape (1, 3, 432, 768)
#
# 102: 432x768 5.1ms, 6 apple
# Speed: 72.9ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# 103: 432x768 16.2ms, 6 apple
# Speed: 69.0ms track, 16.2ms solution per image at shape (1, 3, 432, 768)
#
# 104: 432x768 18.0ms, 6 apple
# Speed: 75.0ms track, 18.0ms solution per image at shape (1, 3, 432, 768)
#
# 105: 432x768 3.4ms, 5 apple
# Speed: 65.8ms track, 3.4ms solution per image at shape (1, 3, 432, 768)
#
# 106: 432x768 9.0ms, 5 apple
# Speed: 64.0ms track, 9.0ms solution per image at shape (1, 3, 432, 768)
#
# 107: 432x768 15.1ms, 5 apple
# Speed: 62.2ms track, 15.1ms solution per image at shape (1, 3, 432, 768)
#
# 108: 432x768 15.5ms, 4 apple
# Speed: 69.1ms track, 15.5ms solution per image at shape (1, 3, 432, 768)
#
# 109: 432x768 6.8ms, 4 apple
# Speed: 72.1ms track, 6.8ms solution per image at shape (1, 3, 432, 768)
#
# 110: 432x768 15.1ms, 4 apple
# Speed: 71.4ms track, 15.1ms solution per image at shape (1, 3, 432, 768)
#
# 111: 432x768 2.7ms, 4 apple
# Speed: 67.5ms track, 2.7ms solution per image at shape (1, 3, 432, 768)
#
# 112: 432x768 5.6ms, 4 apple
# Speed: 63.1ms track, 5.6ms solution per image at shape (1, 3, 432, 768)
#
# 113: 432x768 5.9ms, 4 apple
# Speed: 68.7ms track, 5.9ms solution per image at shape (1, 3, 432, 768)
#
# 114: 432x768 5.0ms, 4 apple
# Speed: 62.1ms track, 5.0ms solution per image at shape (1, 3, 432, 768)
#
# 115: 432x768 7.8ms, 4 apple
# Speed: 58.0ms track, 7.8ms solution per image at shape (1, 3, 432, 768)
#
# 116: 432x768 6.4ms, 4 apple
# Speed: 58.3ms track, 6.4ms solution per image at shape (1, 3, 432, 768)
#
# 117: 432x768 4.4ms, 3 apple
# Speed: 67.9ms track, 4.4ms solution per image at shape (1, 3, 432, 768)
#
# 118: 432x768 5.2ms, 3 apple
# Speed: 62.6ms track, 5.2ms solution per image at shape (1, 3, 432, 768)
#
# 119: 432x768 8.5ms, 3 apple
# Speed: 66.0ms track, 8.5ms solution per image at shape (1, 3, 432, 768)
#
# 120: 432x768 12.2ms, 2 apple
# Speed: 61.0ms track, 12.2ms solution per image at shape (1, 3, 432, 768)
#
# 121: 432x768 13.6ms, 3 apple
# Speed: 60.7ms track, 13.6ms solution per image at shape (1, 3, 432, 768)
#
# 122: 432x768 7.0ms, 4 apple
# Speed: 67.0ms track, 7.0ms solution per image at shape (1, 3, 432, 768)
#
# 123: 432x768 13.5ms, 4 apple
# Speed: 60.9ms track, 13.5ms solution per image at shape (1, 3, 432, 768)
#
# 124: 432x768 4.3ms, 4 apple
# Speed: 69.5ms track, 4.3ms solution per image at shape (1, 3, 432, 768)
#
# 125: 432x768 8.5ms, 4 apple
# Speed: 65.9ms track, 8.5ms solution per image at shape (1, 3, 432, 768)
#
# 126: 432x768 7.4ms, 4 apple
# Speed: 67.1ms track, 7.4ms solution per image at shape (1, 3, 432, 768)
#
# 127: 432x768 11.7ms, 4 apple
# Speed: 63.4ms track, 11.7ms solution per image at shape (1, 3, 432, 768)
#
# 128: 432x768 11.5ms, 4 apple
# Speed: 62.4ms track, 11.5ms solution per image at shape (1, 3, 432, 768)
#
# 129: 432x768 7.7ms, 4 apple
# Speed: 65.3ms track, 7.7ms solution per image at shape (1, 3, 432, 768)
#
# 130: 432x768 12.6ms, 4 apple
# Speed: 76.9ms track, 12.6ms solution per image at shape (1, 3, 432, 768)
#
# 131: 432x768 4.8ms, 4 apple
# Speed: 83.7ms track, 4.8ms solution per image at shape (1, 3, 432, 768)
#
# 132: 432x768 11.3ms, 4 apple
# Speed: 76.2ms track, 11.3ms solution per image at shape (1, 3, 432, 768)
#
# 133: 432x768 9.1ms, 4 apple, 1 orange
# Speed: 65.6ms track, 9.1ms solution per image at shape (1, 3, 432, 768)
#
# 134: 432x768 17.1ms, 4 apple, 1 orange
# Speed: 72.3ms track, 17.1ms solution per image at shape (1, 3, 432, 768)
#
# 135: 432x768 18.6ms, 4 apple, 1 orange
# Speed: 71.2ms track, 18.6ms solution per image at shape (1, 3, 432, 768)
#
# 136: 432x768 17.1ms, 4 apple, 1 orange
# Speed: 71.8ms track, 17.1ms solution per image at shape (1, 3, 432, 768)
#
# 137: 432x768 7.7ms, 5 apple, 1 orange
# Speed: 66.9ms track, 7.7ms solution per image at shape (1, 3, 432, 768)
#
# 138: 432x768 12.2ms, 5 apple, 1 orange
# Speed: 61.8ms track, 12.2ms solution per image at shape (1, 3, 432, 768)
#
# 139: 432x768 8.4ms, 4 apple, 1 orange
# Speed: 65.0ms track, 8.4ms solution per image at shape (1, 3, 432, 768)
#
# 140: 432x768 7.8ms, 3 apple, 2 orange
# Speed: 66.0ms track, 7.8ms solution per image at shape (1, 3, 432, 768)
#
# 141: 432x768 5.5ms, 3 apple, 3 orange
# Speed: 69.1ms track, 5.5ms solution per image at shape (1, 3, 432, 768)
#
# 142: 432x768 6.8ms, 2 apple, 2 orange
# Speed: 67.3ms track, 6.8ms solution per image at shape (1, 3, 432, 768)
#
# 143: 432x768 4.7ms, 2 apple, 2 orange
# Speed: 70.1ms track, 4.7ms solution per image at shape (1, 3, 432, 768)
#
# 144: 432x768 7.1ms, 2 apple, 2 orange
# Speed: 66.1ms track, 7.1ms solution per image at shape (1, 3, 432, 768)
#
# 145: 432x768 10.2ms, 3 apple, 2 orange
# Speed: 63.5ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# 146: 432x768 3.4ms, 2 apple, 1 orange
# Speed: 70.5ms track, 3.4ms solution per image at shape (1, 3, 432, 768)
#
# 147: 432x768 11.0ms, 2 apple, 2 orange
# Speed: 64.2ms track, 11.0ms solution per image at shape (1, 3, 432, 768)
#
# 148: 432x768 17.8ms, 2 apple, 2 orange
# Speed: 71.8ms track, 17.8ms solution per image at shape (1, 3, 432, 768)
#
# 149: 432x768 6.7ms, 2 apple, 2 orange
# Speed: 66.7ms track, 6.7ms solution per image at shape (1, 3, 432, 768)
#
# 150: 432x768 3.5ms, 2 apple, 2 orange
# Speed: 70.0ms track, 3.5ms solution per image at shape (1, 3, 432, 768)
#
# 151: 432x768 13.4ms, 1 apple, 2 orange
# Speed: 60.6ms track, 13.4ms solution per image at shape (1, 3, 432, 768)
#
# 152: 432x768 17.3ms, 2 apple, 2 orange
# Speed: 72.2ms track, 17.3ms solution per image at shape (1, 3, 432, 768)
#
# 153: 432x768 5.0ms, 1 apple, 2 orange
# Speed: 68.5ms track, 5.0ms solution per image at shape (1, 3, 432, 768)
#
# 154: 432x768 4.2ms, 2 orange
# Speed: 70.9ms track, 4.2ms solution per image at shape (1, 3, 432, 768)
#
# 155: 432x768 12.3ms, 2 orange
# Speed: 60.9ms track, 12.3ms solution per image at shape (1, 3, 432, 768)
#
# 156: 432x768 8.8ms, 2 orange
# Speed: 64.4ms track, 8.8ms solution per image at shape (1, 3, 432, 768)
#
# 157: 432x768 12.7ms, 2 orange
# Speed: 60.8ms track, 12.7ms solution per image at shape (1, 3, 432, 768)
#
# 158: 432x768 12.7ms, 2 orange
# Speed: 62.4ms track, 12.7ms solution per image at shape (1, 3, 432, 768)
#
# 159: 432x768 7.0ms, 1 orange
# Speed: 67.6ms track, 7.0ms solution per image at shape (1, 3, 432, 768)
#
# 160: 432x768 9.0ms, 2 orange
# Speed: 65.9ms track, 9.0ms solution per image at shape (1, 3, 432, 768)
#
# 161: 432x768 13.9ms, 2 orange
# Speed: 61.3ms track, 13.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 162: 432x768 18.0ms,
# Speed: 56.8ms track, 18.0ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 163: 432x768 16.2ms,
# Speed: 57.5ms track, 16.2ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 164: 432x768 2.3ms,
# Speed: 70.1ms track, 2.3ms solution per image at shape (1, 3, 432, 768)
#
# 165: 432x768 10.2ms, 2 orange
# Speed: 64.6ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 166: 432x768 10.8ms,
# Speed: 63.3ms track, 10.8ms solution per image at shape (1, 3, 432, 768)
#
# 167: 432x768 10.2ms, 1 apple
# Speed: 64.9ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# 168: 432x768 9.2ms, 1 apple, 2 orange
# Speed: 72.1ms track, 9.2ms solution per image at shape (1, 3, 432, 768)
#
# 169: 432x768 6.2ms, 2 orange
# Speed: 61.2ms track, 6.2ms solution per image at shape (1, 3, 432, 768)
#
# 170: 432x768 4.7ms, 1 apple, 1 orange
# Speed: 60.9ms track, 4.7ms solution per image at shape (1, 3, 432, 768)
#
# 171: 432x768 5.8ms, 1 orange
# Speed: 67.4ms track, 5.8ms solution per image at shape (1, 3, 432, 768)
#
# 172: 432x768 8.5ms, 2 orange
# Speed: 70.1ms track, 8.5ms solution per image at shape (1, 3, 432, 768)
#
# 173: 432x768 4.6ms, 1 apple
# Speed: 61.6ms track, 4.6ms solution per image at shape (1, 3, 432, 768)
#
# 174: 432x768 9.4ms, 2 apple, 1 orange
# Speed: 62.3ms track, 9.4ms solution per image at shape (1, 3, 432, 768)
#
# 175: 432x768 5.6ms, 1 apple
# Speed: 60.6ms track, 5.6ms solution per image at shape (1, 3, 432, 768)
#
# 176: 432x768 5.1ms, 1 apple
# Speed: 60.2ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# 177: 432x768 3.3ms, 1 apple
# Speed: 62.3ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 178: 432x768 6.9ms, 1 apple
# Speed: 59.5ms track, 6.9ms solution per image at shape (1, 3, 432, 768)
#
# 179: 432x768 14.0ms, 1 apple
# Speed: 58.7ms track, 14.0ms solution per image at shape (1, 3, 432, 768)
#
# 180: 432x768 16.3ms, 1 apple
# Speed: 57.4ms track, 16.3ms solution per image at shape (1, 3, 432, 768)
#
# 181: 432x768 5.7ms, 1 apple
# Speed: 60.1ms track, 5.7ms solution per image at shape (1, 3, 432, 768)
#
# 182: 432x768 5.8ms, 1 apple
# Speed: 60.8ms track, 5.8ms solution per image at shape (1, 3, 432, 768)
#
# 183: 432x768 8.4ms, 1 apple
# Speed: 64.4ms track, 8.4ms solution per image at shape (1, 3, 432, 768)
#
# 184: 432x768 3.1ms, 1 apple
# Speed: 62.3ms track, 3.1ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 185: 432x768 3.0ms,
# Speed: 62.9ms track, 3.0ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 186: 432x768 3.5ms,
# Speed: 57.4ms track, 3.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 187: 432x768 10.7ms,
# Speed: 59.2ms track, 10.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 188: 432x768 6.5ms,
# Speed: 61.2ms track, 6.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 189: 432x768 9.7ms,
# Speed: 63.4ms track, 9.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 190: 432x768 5.5ms,
# Speed: 59.9ms track, 5.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 191: 432x768 9.8ms,
# Speed: 62.9ms track, 9.8ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 192: 432x768 8.4ms,
# Speed: 57.9ms track, 8.4ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 193: 432x768 4.3ms,
# Speed: 75.5ms track, 4.3ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 194: 432x768 6.3ms,
# Speed: 67.3ms track, 6.3ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 195: 432x768 2.6ms,
# Speed: 61.0ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 196: 432x768 5.6ms,
# Speed: 60.7ms track, 5.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 197: 432x768 17.7ms,
# Speed: 69.4ms track, 17.7ms solution per image at shape (1, 3, 432, 768)
#
# 198: 432x768 9.1ms, 1 orange
# Speed: 79.0ms track, 9.1ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 199: 432x768 17.1ms,
# Speed: 84.1ms track, 17.1ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 200: 432x768 13.3ms,
# Speed: 75.3ms track, 13.3ms solution per image at shape (1, 3, 432, 768)
#
# 201: 432x768 4.3ms, 1 orange
# Speed: 68.6ms track, 4.3ms solution per image at shape (1, 3, 432, 768)
#
# 202: 432x768 15.3ms, 1 orange
# Speed: 57.9ms track, 15.3ms solution per image at shape (1, 3, 432, 768)
#
# 203: 432x768 15.9ms, 1 apple
# Speed: 60.3ms track, 15.9ms solution per image at shape (1, 3, 432, 768)
#
# 204: 432x768 5.4ms, 2 apple
# Speed: 68.4ms track, 5.4ms solution per image at shape (1, 3, 432, 768)
#
# 205: 432x768 8.7ms, 1 apple, 1 orange
# Speed: 64.6ms track, 8.7ms solution per image at shape (1, 3, 432, 768)
#
# 206: 432x768 5.3ms, 1 apple, 1 orange
# Speed: 68.8ms track, 5.3ms solution per image at shape (1, 3, 432, 768)
#
# 207: 432x768 10.5ms, 1 apple
# Speed: 63.8ms track, 10.5ms solution per image at shape (1, 3, 432, 768)
#
# 208: 432x768 9.3ms, 1 apple
# Speed: 63.5ms track, 9.3ms solution per image at shape (1, 3, 432, 768)
#
# 209: 432x768 10.3ms, 1 apple
# Speed: 62.2ms track, 10.3ms solution per image at shape (1, 3, 432, 768)
#
# 210: 432x768 12.9ms, 1 apple
# Speed: 62.1ms track, 12.9ms solution per image at shape (1, 3, 432, 768)
#
# 211: 432x768 2.7ms, 2 apple
# Speed: 68.9ms track, 2.7ms solution per image at shape (1, 3, 432, 768)
#
# 212: 432x768 15.2ms, 2 apple
# Speed: 60.4ms track, 15.2ms solution per image at shape (1, 3, 432, 768)
#
# 213: 432x768 11.5ms, 2 apple
# Speed: 62.5ms track, 11.5ms solution per image at shape (1, 3, 432, 768)
#
# 214: 432x768 12.2ms, 2 apple
# Speed: 61.8ms track, 12.2ms solution per image at shape (1, 3, 432, 768)
#
# 215: 432x768 16.4ms, 2 apple
# Speed: 87.7ms track, 16.4ms solution per image at shape (1, 3, 432, 768)
#
# 216: 432x768 5.1ms, 2 apple
# Speed: 71.1ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# 217: 432x768 15.7ms, 2 apple
# Speed: 74.0ms track, 15.7ms solution per image at shape (1, 3, 432, 768)
#
# 218: 432x768 10.8ms, 2 apple
# Speed: 63.1ms track, 10.8ms solution per image at shape (1, 3, 432, 768)
#
# 219: 432x768 6.5ms, 3 apple
# Speed: 65.7ms track, 6.5ms solution per image at shape (1, 3, 432, 768)
#
# 220: 432x768 13.6ms, 5 apple
# Speed: 59.2ms track, 13.6ms solution per image at shape (1, 3, 432, 768)
#
# 221: 432x768 14.5ms, 5 apple
# Speed: 60.7ms track, 14.5ms solution per image at shape (1, 3, 432, 768)
#
# 222: 432x768 12.4ms, 5 apple
# Speed: 63.1ms track, 12.4ms solution per image at shape (1, 3, 432, 768)
#
# 223: 432x768 12.6ms, 5 apple
# Speed: 62.4ms track, 12.6ms solution per image at shape (1, 3, 432, 768)
#
# 224: 432x768 12.4ms, 5 apple
# Speed: 60.9ms track, 12.4ms solution per image at shape (1, 3, 432, 768)
#
# 225: 432x768 14.4ms, 5 apple
# Speed: 61.4ms track, 14.4ms solution per image at shape (1, 3, 432, 768)
#
# 226: 432x768 16.7ms, 5 apple
# Speed: 58.5ms track, 16.7ms solution per image at shape (1, 3, 432, 768)
#
# 227: 432x768 4.7ms, 5 apple
# Speed: 69.8ms track, 4.7ms solution per image at shape (1, 3, 432, 768)
#
# 228: 432x768 5.2ms, 5 apple
# Speed: 69.6ms track, 5.2ms solution per image at shape (1, 3, 432, 768)
#
# 229: 432x768 2.9ms, 4 apple
# Speed: 72.3ms track, 2.9ms solution per image at shape (1, 3, 432, 768)
#
# 230: 432x768 2.5ms, 3 apple
# Speed: 69.4ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# 231: 432x768 2.7ms, 3 apple
# Speed: 69.9ms track, 2.7ms solution per image at shape (1, 3, 432, 768)
#
# 232: 432x768 2.5ms, 4 apple
# Speed: 75.3ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# 233: 432x768 2.5ms, 4 apple
# Speed: 74.6ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# 234: 432x768 7.4ms, 1 apple
# Speed: 76.6ms track, 7.4ms solution per image at shape (1, 3, 432, 768)
#
# 235: 432x768 16.1ms, 3 apple
# Speed: 72.7ms track, 16.1ms solution per image at shape (1, 3, 432, 768)
#
# 236: 432x768 5.1ms, 4 apple
# Speed: 68.1ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# 237: 432x768 2.3ms, 1 apple
# Speed: 67.7ms track, 2.3ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 238: 432x768 2.6ms,
# Speed: 76.2ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 239: 432x768 2.5ms,
# Speed: 74.7ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 240: 432x768 2.9ms,
# Speed: 66.9ms track, 2.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 241: 432x768 2.5ms,
# Speed: 72.0ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 242: 432x768 16.2ms,
# Speed: 68.9ms track, 16.2ms solution per image at shape (1, 3, 432, 768)
#
# 243: 432x768 6.6ms, 2 apple
# Speed: 66.2ms track, 6.6ms solution per image at shape (1, 3, 432, 768)
#
# 244: 432x768 6.8ms, 3 apple
# Speed: 67.5ms track, 6.8ms solution per image at shape (1, 3, 432, 768)
#
# 245: 432x768 8.1ms, 3 apple
# Speed: 72.6ms track, 8.1ms solution per image at shape (1, 3, 432, 768)
#
# 246: 432x768 3.3ms, 1 apple
# Speed: 78.5ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 247: 432x768 10.9ms, 1 apple
# Speed: 72.4ms track, 10.9ms solution per image at shape (1, 3, 432, 768)
#
# 248: 432x768 2.5ms, 2 apple
# Speed: 71.2ms track, 2.5ms solution per image at shape (1, 3, 432, 768)
#
# 249: 432x768 3.5ms, 3 apple
# Speed: 72.3ms track, 3.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 250: 432x768 2.6ms,
# Speed: 65.8ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 251: 432x768 2.6ms,
# Speed: 70.2ms track, 2.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 252: 432x768 2.7ms,
# Speed: 63.2ms track, 2.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 253: 432x768 2.9ms,
# Speed: 59.3ms track, 2.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 254: 432x768 2.9ms,
# Speed: 70.3ms track, 2.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 255: 432x768 3.9ms,
# Speed: 92.7ms track, 3.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 256: 432x768 2.7ms,
# Speed: 78.1ms track, 2.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 257: 432x768 9.4ms,
# Speed: 67.4ms track, 9.4ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 258: 432x768 16.9ms,
# Speed: 64.0ms track, 16.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 259: 432x768 5.3ms,
# Speed: 66.1ms track, 5.3ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 260: 432x768 9.8ms,
# Speed: 70.0ms track, 9.8ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 261: 432x768 6.8ms,
# Speed: 66.7ms track, 6.8ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 262: 432x768 2.9ms,
# Speed: 90.3ms track, 2.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 263: 432x768 3.8ms,
# Speed: 77.0ms track, 3.8ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 264: 432x768 8.7ms,
# Speed: 70.4ms track, 8.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 265: 432x768 7.9ms,
# Speed: 64.1ms track, 7.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 266: 432x768 4.2ms,
# Speed: 61.6ms track, 4.2ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 267: 432x768 4.6ms,
# Speed: 68.2ms track, 4.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 268: 432x768 3.8ms,
# Speed: 64.3ms track, 3.8ms solution per image at shape (1, 3, 432, 768)
#
# 269: 432x768 6.9ms, 1 apple
# Speed: 71.5ms track, 6.9ms solution per image at shape (1, 3, 432, 768)
#
# 270: 432x768 15.3ms, 1 apple
# Speed: 67.2ms track, 15.3ms solution per image at shape (1, 3, 432, 768)
#
# 271: 432x768 17.5ms, 1 apple
# Speed: 71.1ms track, 17.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 272: 432x768 12.7ms,
# Speed: 61.1ms track, 12.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 273: 432x768 4.9ms,
# Speed: 68.6ms track, 4.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 274: 432x768 16.5ms,
# Speed: 72.7ms track, 16.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 275: 432x768 18.3ms,
# Speed: 70.4ms track, 18.3ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 276: 432x768 3.8ms,
# Speed: 69.6ms track, 3.8ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 277: 432x768 17.4ms,
# Speed: 70.4ms track, 17.4ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 278: 432x768 7.6ms,
# Speed: 66.7ms track, 7.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 279: 432x768 6.6ms,
# Speed: 67.6ms track, 6.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 280: 432x768 8.6ms,
# Speed: 66.7ms track, 8.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 281: 432x768 4.6ms,
# Speed: 70.3ms track, 4.6ms solution per image at shape (1, 3, 432, 768)
#
# 282: 432x768 7.0ms, 1 apple
# Speed: 67.0ms track, 7.0ms solution per image at shape (1, 3, 432, 768)
#
# 283: 432x768 3.2ms, 2 apple
# Speed: 70.8ms track, 3.2ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 284: 432x768 9.7ms,
# Speed: 65.1ms track, 9.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 285: 432x768 5.1ms,
# Speed: 68.3ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 286: 432x768 7.7ms,
# Speed: 67.6ms track, 7.7ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 287: 432x768 6.9ms,
# Speed: 68.9ms track, 6.9ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 288: 432x768 7.6ms,
# Speed: 66.5ms track, 7.6ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 289: 432x768 6.5ms,
# Speed: 67.6ms track, 6.5ms solution per image at shape (1, 3, 432, 768)
#
# WARNING No tracks found.
# 290: 432x768 3.3ms,
# Speed: 69.5ms track, 3.3ms solution per image at shape (1, 3, 432, 768)
#
# 291: 432x768 17.2ms, 1 apple
# Speed: 71.4ms track, 17.2ms solution per image at shape (1, 3, 432, 768)
#
# 292: 432x768 8.8ms, 1 apple
# Speed: 66.8ms track, 8.8ms solution per image at shape (1, 3, 432, 768)
#
# 293: 432x768 6.3ms, 1 apple
# Speed: 67.4ms track, 6.3ms solution per image at shape (1, 3, 432, 768)
#
# 294: 432x768 4.5ms, 2 apple
# Speed: 70.4ms track, 4.5ms solution per image at shape (1, 3, 432, 768)
#
# 295: 432x768 8.1ms, 2 apple
# Speed: 66.7ms track, 8.1ms solution per image at shape (1, 3, 432, 768)
#
# 296: 432x768 8.9ms, 1 apple
# Speed: 67.2ms track, 8.9ms solution per image at shape (1, 3, 432, 768)
#
# 297: 432x768 10.2ms, 2 apple
# Speed: 63.3ms track, 10.2ms solution per image at shape (1, 3, 432, 768)
#
# 298: 432x768 6.6ms, 2 apple
# Speed: 65.9ms track, 6.6ms solution per image at shape (1, 3, 432, 768)
#
# 299: 432x768 3.6ms, 2 apple
# Speed: 69.5ms track, 3.6ms solution per image at shape (1, 3, 432, 768)
#
# 300: 432x768 5.1ms, 2 apple
# Speed: 68.4ms track, 5.1ms solution per image at shape (1, 3, 432, 768)
#
# 301: 432x768 4.2ms, 2 apple
# Speed: 68.6ms track, 4.2ms solution per image at shape (1, 3, 432, 768)
#
# 302: 432x768 7.0ms, 3 apple
# Speed: 67.0ms track, 7.0ms solution per image at shape (1, 3, 432, 768)
#
# 303: 432x768 15.5ms, 3 apple
# Speed: 59.1ms track, 15.5ms solution per image at shape (1, 3, 432, 768)
#
# 304: 432x768 6.2ms, 3 apple
# Speed: 66.7ms track, 6.2ms solution per image at shape (1, 3, 432, 768)
#
# 305: 432x768 18.0ms, 2 apple
# Speed: 72.7ms track, 18.0ms solution per image at shape (1, 3, 432, 768)
#
# 306: 432x768 10.1ms, 2 apple
# Speed: 65.1ms track, 10.1ms solution per image at shape (1, 3, 432, 768)
#
# 307: 432x768 9.4ms, 2 apple
# Speed: 64.5ms track, 9.4ms solution per image at shape (1, 3, 432, 768)
#
# 308: 432x768 9.5ms, 2 apple
# Speed: 65.7ms track, 9.5ms solution per image at shape (1, 3, 432, 768)
#
# 309: 432x768 4.0ms, 3 apple
# Speed: 68.6ms track, 4.0ms solution per image at shape (1, 3, 432, 768)
#
# Video frame is empty or processing is complete.
